# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(font="IPAexGothic",style="white")

# %%
train = pd.read_csv("/content/drive/My Drive/Colab Notebooks/signate_obentou/train.csv")
test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/signate_obentou/test.csv")
sample = pd.read_csv("/content/drive/My Drive/Colab Notebooks/signate_obentou/sample.csv",header=None)
print("Data Shapes")
print("Train:",train.shape, "Test:",test.shape, "Sample:",sample.shape)
# Out:
# Data Shapes
# Train: (207, 12) Test: (40, 11) Sample: (40, 2)

# %%
train.head()
# Out:
#      datetime    y week  soldout  ... payday  weather precipitation temperature
# 0  2013-11-18   90    月        0  ...    NaN       快晴            --        19.8
# 1  2013-11-19  101    火        1  ...    NaN       快晴            --        17.0
# 2  2013-11-20  118    水        0  ...    NaN       快晴            --        15.5
# 3  2013-11-21  120    木        1  ...    NaN       快晴            --        15.2
# 4  2013-11-22  130    金        1  ...    NaN       快晴            --        16.1
#
# [5 rows x 12 columns]

# %%
train.describe()
# Out:
#                 y     soldout        kcal  payday  temperature
# count  207.000000  207.000000  166.000000    10.0   207.000000
# mean    86.623188    0.449275  404.409639     1.0    19.252174
# std     32.882448    0.498626   29.884641     0.0     8.611365
# min     29.000000    0.000000  315.000000     1.0     1.200000
# 25%     57.000000    0.000000  386.000000     1.0    11.550000
# 50%     78.000000    0.000000  408.500000     1.0    19.800000
# 75%    113.000000    1.000000  426.000000     1.0    26.100000
# max    171.000000    1.000000  462.000000     1.0    34.600000

# %%
train.describe(include="O")
# Out:
#          datetime week   name   remarks event weather precipitation
# count         207  207    207        21    14     207           207
# unique        207    5    156         6     2       7             8
# top     2014-3-26    水  メンチカツ  お楽しみメニュー  ママの会      快晴            --
# freq            1   43      6        12     9      53           169

# %%
train.isnull().sum()
# Out:
# datetime           0
# y                  0
# week               0
# soldout            0
# name               0
# kcal              41
# remarks          186
# event            193
# payday           197
# weather            0
# precipitation      0
# temperature        0
# dtype: int64

# %%
train["payday"] = train["payday"].fillna(0)
train["precipitation"] = train["precipitation"].apply(lambda x : -1 if x == "--" else float(x))
train["event"] = train["event"].fillna("なし")
train["remarks"] = train["remarks"].fillna("なし")
train["month"] = train["datetime"].apply(lambda x : int(x.split("-")[1]))

# %%
train
# Out:
#        datetime    y week  soldout  ... weather  precipitation temperature month
# 0    2013-11-18   90    月        0  ...      快晴           -1.0        19.8    11
# 1    2013-11-19  101    火        1  ...      快晴           -1.0        17.0    11
# 2    2013-11-20  118    水        0  ...      快晴           -1.0        15.5    11
# 3    2013-11-21  120    木        1  ...      快晴           -1.0        15.2    11
# 4    2013-11-22  130    金        1  ...      快晴           -1.0        16.1    11
# ..          ...  ...  ...      ...  ...     ...            ...         ...   ...
# 202   2014-9-24   59    水        1  ...       曇            0.0        24.8     9
# 203   2014-9-25   50    木        0  ...       曇            0.0        25.4     9
# 204   2014-9-26   45    金        0  ...      晴れ           -1.0        27.1     9
# 205   2014-9-29   56    月        1  ...      快晴           -1.0        26.6     9
# 206   2014-9-30   40    火        0  ...      快晴           -1.0        28.1     9
#
# ...

# %%
train.index = pd.to_datetime(train["datetime"])
train.head()
# Out:
#               datetime    y week  ...  precipitation temperature  month
# datetime                          ...
# 2013-11-18  2013-11-18   90    月  ...           -1.0        19.8     11
# 2013-11-19  2013-11-19  101    火  ...           -1.0        17.0     11
# 2013-11-20  2013-11-20  118    水  ...           -1.0        15.5     11
# 2013-11-21  2013-11-21  120    木  ...           -1.0        15.2     11
# 2013-11-22  2013-11-22  130    金  ...           -1.0        16.1     11
#
# [5 rows x 13 columns]

# %%
train["y"].plot(figsize=(15,4))
# Out:
# findfont: Font family ['IPAexGothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['IPAexGothic'] not found. Falling back to DejaVu Sans.

# %%
fig, ax = plt.subplots(2,3,figsize=(9,6))
train.plot.scatter(x="soldout", y="y", ax=ax[0][0])
train.plot.scatter(x="kcal", y="y", ax=ax[0][1])
train.plot.scatter(x="precipitation", y="y", ax=ax[0][2])
train.plot.scatter(x="payday", y="y", ax=ax[1][0])
train.plot.scatter(x="temperature", y="y", ax=ax[1][1])
train.plot.scatter(x="month", y="y", ax=ax[1][2])
plt.tight_layout()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %%
ax
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fda739c20d0>,
# ...
#       dtype=object)

# %%
fig, ax = plt.subplots(2,2,figsize=(12,7))
sns.boxplot(x="week",y="y",data=train,ax=ax[0][0])
sns.boxplot(x="weather",y="y",data=train,ax=ax[0][1])
sns.boxplot(x="remarks",y="y",data=train,ax=ax[1][0])
ax[1][0].set_xticklabels(ax[1][0].get_xticklabels(),rotation=30)
sns.boxplot(x="event",y="y",data=train,ax=ax[1][1])
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26376 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 28779 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 27700 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 26408 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 37329 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
train["remarks"]
# Out:
# datetime
# 2013-11-18                 なし
# 2013-11-19                 なし
# 2013-11-20                 なし
# 2013-11-21                 なし
# 2013-11-22                 なし
#                    ...
# 2014-09-24                 なし
# 2014-09-25                 なし
# 2014-09-26    スペシャルメニュー（800円）
# 2014-09-29                 なし
# 2014-09-30                 なし
# Name: remarks, Length: 207, dtype: object

# %%
train[train["remarks"]!="お楽しみメニュー"]["y"].plot(figsize=(15,4))

# %%
train["y"].plot(figsize=(15,4))

# %%
train["fun"] = train["remarks"].apply(lambda x: 1 if x=="お楽しみメニュー" else 0)
sns.boxplot(x="fun",y="y",data=train)

# %%
from scipy.stats import median_test
stat,p,med,tbl = median_test(train[train["fun"]==1]["y"],train[train["fun"]==0]["y"])
print("p",p,"stat",stat)
# Out:
# p 0.007057960766247775 stat 7.2581589841730345

# %%
train[train["remarks"]=="お楽しみメニュー"]["y"].plot(figsize=(15,4))

# %%
train[train["remarks"]=="お楽しみメニュー"]
# Out:
#              datetime    y week  ...  temperature month  fun
# datetime                         ...
# 2014-03-28  2014-3-28  106    金  ...         18.5     3    1
# 2014-04-11  2014-4-11  128    金  ...         16.5     4    1
# 2014-04-25  2014-4-25   80    金  ...         20.8     4    1
# 2014-05-16  2014-5-16  126    金  ...         23.8     5    1
# 2014-05-30  2014-5-30  119    金  ...         26.9     5    1
# 2014-06-13  2014-6-13  121    金  ...         29.5     6    1
# 2014-06-27  2014-6-27   74    金  ...         25.4     6    1
# 2014-07-11  2014-7-11  124    金  ...         33.9     7    1
# 2014-07-25  2014-7-25   83    金  ...         33.6     7    1
# 2014-08-08   2014-8-8  129    金  ...         31.1     8    1
# 2014-08-22  2014-8-22  100    金  ...         33.1     8    1
# 2014-09-12  2014-9-12  115    金  ...         27.3     9    1
#
# [12 rows x 14 columns]

# %%
train_remarks = train[train["remarks"]=="お楽しみメニュー"]
train_remarks.plot.scatter(x="datetime", y="y")
plt.tight_layout()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
train["curry"] = train["name"].apply(lambda x : 1 if x.find("カレー")>=0 else 0)
sns.boxplot(x="curry",y="y",data=train)

# %%
stat,p,med,tbl = median_test(train[train["curry"]==1]["y"],train[train["curry"]==0]["y"])
print("p:",p,"stat",stat)
# Out:
# p: 0.010699742900892427 stat 6.514516162828877

# %%
train = pd.read_csv("/content/drive/My Drive/Colab Notebooks/signate_obentou/train.csv")
test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/signate_obentou/test.csv")
sample = pd.read_csv("/content/drive/My Drive/Colab Notebooks/signate_obentou/sample.csv",header=None)

# %%
train["t"] = 1
test["t"] = 0
dat = pd.concat([train,test],sort=True).reset_index(drop=True)

# %%
dat
# Out:
#        datetime event   kcal          name  ...  temperature weather week      y
# 0    2013-11-18   NaN    NaN      厚切りイカフライ  ...         19.8      快晴    月   90.0
# 1    2013-11-19   NaN    NaN       手作りヒレカツ  ...         17.0      快晴    火  101.0
# 2    2013-11-20   NaN    NaN    白身魚唐揚げ野菜あん  ...         15.5      快晴    水  118.0
# 3    2013-11-21   NaN    NaN        若鶏ピリ辛焼  ...         15.2      快晴    木  120.0
# 4    2013-11-22   NaN    NaN      ビッグメンチカツ  ...         16.1      快晴    金  130.0
# ..          ...   ...    ...           ...  ...          ...     ...  ...    ...
# 242  2014-11-21   NaN    NaN         ロコモコ丼  ...         14.9      快晴    金    NaN
# 243  2014-11-25   NaN  460.0   なすと挽肉のはさみ揚げ  ...         11.4       雨    火    NaN
# 244  2014-11-26   NaN  415.0       鶏肉の治部煮風  ...          9.2       雨    水    NaN
# 245  2014-11-27   NaN  420.0           牛丼風  ...         15.1      快晴    木    NaN
# 246  2014-11-28   NaN  416.0  鶏肉のスイートチリソース  ...         15.3       曇    金    NaN
#
# ...

# %%
print(train.shape,test.shape,dat.shape)
# Out:
# (207, 13) (40, 12) (247, 13)

# %%
dat.index = pd.to_datetime(dat["datetime"])
dat
# Out:
#               datetime event   kcal  ... weather  week      y
# datetime                             ...
# 2013-11-18  2013-11-18   NaN    NaN  ...      快晴     月   90.0
# 2013-11-19  2013-11-19   NaN    NaN  ...      快晴     火  101.0
# 2013-11-20  2013-11-20   NaN    NaN  ...      快晴     水  118.0
# 2013-11-21  2013-11-21   NaN    NaN  ...      快晴     木  120.0
# 2013-11-22  2013-11-22   NaN    NaN  ...      快晴     金  130.0
# ...                ...   ...    ...  ...     ...   ...    ...
# 2014-11-21  2014-11-21   NaN    NaN  ...      快晴     金    NaN
# 2014-11-25  2014-11-25   NaN  460.0  ...       雨     火    NaN
# 2014-11-26  2014-11-26   NaN  415.0  ...       雨     水    NaN
# 2014-11-27  2014-11-27   NaN  420.0  ...      快晴     木    NaN
# 2014-11-28  2014-11-28   NaN  416.0  ...       曇     金    NaN
#
# [247 rows x 13 columns]

# %%
dat = dat["2014-05-01":]
dat
# Out:
#               datetime event   kcal  ... weather  week     y
# datetime                             ...
# 2014-05-01    2014-5-1   NaN  415.0  ...      晴れ     木  64.0
# 2014-05-02    2014-5-2   NaN  420.0  ...      晴れ     金  47.0
# 2014-05-07    2014-5-7   NaN  415.0  ...      晴れ     水  88.0
# 2014-05-08    2014-5-8   NaN  405.0  ...      薄曇     木  59.0
# 2014-05-09    2014-5-9   NaN  434.0  ...      晴れ     金  58.0
# ...                ...   ...    ...  ...     ...   ...   ...
# 2014-11-21  2014-11-21   NaN    NaN  ...      快晴     金   NaN
# 2014-11-25  2014-11-25   NaN  460.0  ...       雨     火   NaN
# 2014-11-26  2014-11-26   NaN  415.0  ...       雨     水   NaN
# 2014-11-27  2014-11-27   NaN  420.0  ...      快晴     木   NaN
# 2014-11-28  2014-11-28   NaN  416.0  ...       曇     金   NaN
#
# [141 rows x 13 columns]

# %%
dat = dat.reset_index(drop=True)
dat
# Out:
#        datetime event   kcal          name  ...  temperature weather week     y
# 0      2014-5-1   NaN  415.0         マーボ茄子  ...         24.0      晴れ    木  64.0
# 1      2014-5-2   NaN  420.0         鶏の天ぷら  ...         23.3      晴れ    金  47.0
# 2      2014-5-7   NaN  415.0          肉じゃが  ...         18.9      晴れ    水  88.0
# 3      2014-5-8   NaN  405.0         メンチカツ  ...         21.0      薄曇    木  59.0
# 4      2014-5-9   NaN  434.0      手作りチキンカツ  ...         23.4      晴れ    金  58.0
# ..          ...   ...    ...           ...  ...          ...     ...  ...   ...
# 136  2014-11-21   NaN    NaN         ロコモコ丼  ...         14.9      快晴    金   NaN
# 137  2014-11-25   NaN  460.0   なすと挽肉のはさみ揚げ  ...         11.4       雨    火   NaN
# 138  2014-11-26   NaN  415.0       鶏肉の治部煮風  ...          9.2       雨    水   NaN
# 139  2014-11-27   NaN  420.0           牛丼風  ...         15.1      快晴    木   NaN
# 140  2014-11-28   NaN  416.0  鶏肉のスイートチリソース  ...         15.3       曇    金   NaN
#
# ...

# %%
dat["days"] = dat.index
dat
# Out:
#        datetime event   kcal          name  ...  weather week     y  days
# 0      2014-5-1   NaN  415.0         マーボ茄子  ...       晴れ    木  64.0     0
# 1      2014-5-2   NaN  420.0         鶏の天ぷら  ...       晴れ    金  47.0     1
# 2      2014-5-7   NaN  415.0          肉じゃが  ...       晴れ    水  88.0     2
# 3      2014-5-8   NaN  405.0         メンチカツ  ...       薄曇    木  59.0     3
# 4      2014-5-9   NaN  434.0      手作りチキンカツ  ...       晴れ    金  58.0     4
# ..          ...   ...    ...           ...  ...      ...  ...   ...   ...
# 136  2014-11-21   NaN    NaN         ロコモコ丼  ...       快晴    金   NaN   136
# 137  2014-11-25   NaN  460.0   なすと挽肉のはさみ揚げ  ...        雨    火   NaN   137
# 138  2014-11-26   NaN  415.0       鶏肉の治部煮風  ...        雨    水   NaN   138
# 139  2014-11-27   NaN  420.0           牛丼風  ...       快晴    木   NaN   139
# 140  2014-11-28   NaN  416.0  鶏肉のスイートチリソース  ...        曇    金   NaN   140
#
# [141 rows x 14 columns]

# %%
dat["precipitation"] = dat["precipitation"].apply(lambda x : -1 if x=="--" else x).astype(np.float)
dat["fun"] = dat["remarks"].apply(lambda x: 1 if x=="お楽しみメニュー" else 0)
dat["curry"] = dat["name"].apply(lambda x : 1 if x.find("カレー")>=0 else 0)
cols = ["precipitation","weather","days","fun","curry","y"]

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error as MSE
from sklearn.linear_model import LinearRegression as LR
from sklearn.ensemble import RandomForestRegressor as RF

# %%
def learning(trainX,y_train):
    model1 = LR()
    model2 = RF(n_estimators=100,max_depth=4,random_state=777)
    model1.fit(trainX["days"].values.reshape(-1,1),y_train)
    pred = model1.predict(trainX["days"].values.reshape(-1,1))
    
    pred_sub = y_train - pred
    model2.fit(trainX.iloc[:, ~trainX.columns.str.match("y")],pred_sub)
    return model1, model2

# %%
kf = KFold(n_splits=5,random_state=777,shuffle=True)
tr = dat[dat["t"]==1][cols]

trains = []
tests = []
for train_index, test_index in kf.split(tr):
    tr.loc[train_index,"tt"] = 1
    tr.loc[test_index,"tt"] = 0
    tr["tt"] = tr["tt"].astype(np.int)
    tmp = pd.get_dummies(tr)
    
    trainX = tmp[tmp["tt"]==1]
    del trainX["tt"]
    testX = tmp[tmp["tt"]==0]
    del testX["tt"]
    y_train = tmp[tmp["tt"]==1]["y"]
    y_test = tmp[tmp["tt"]==0]["y"]
    
    model1, model2 = learning(trainX, y_train)
    
    pred_train = model1.predict(trainX["days"].values.reshape(-1,1)) + model2.predict(trainX.iloc[:, ~trainX.columns.str.match("y")])
    pred_test = model1.predict(testX["days"].values.reshape(-1,1)) + model2.predict(testX.iloc[:, ~testX.columns.str.match("y")])
    
    print("TRAIN:",MSE(y_train,pred_train)**0.5, "VARIDATE",MSE(y_test, pred_test)**0.5)
    trains.append(MSE(y_train,pred_train)**0.5)
    tests.append(MSE(y_test, pred_test)**0.5)
print("AVG")
print(np.array(trains).mean(), np.array(tests).mean())
# Out:
# TRAIN: 7.878691946699353 VARIDATE 10.756255997126631
# TRAIN: 7.934279650168929 VARIDATE 10.226259072591304
# TRAIN: 8.223365349030384 VARIDATE 7.654816188613056
# TRAIN: 7.262769357987639 VARIDATE 13.826314671505262
# TRAIN: 8.167632911501304 VARIDATE 9.619186475024971
# AVG
# 7.893347843077523 10.416566480972245

# %%
cols = ["precipitation","weather","days","fun","curry","y","t"]
tmp = pd.get_dummies(dat[cols])
trainX = tmp[tmp["t"]==1]
del trainX["t"]
testX = tmp[tmp["t"]==0]
del testX["t"]
y_train = tmp[tmp["t"]==1]["y"]
y_test = tmp[tmp["t"]==0]["y"]

# %%
model1, model2 = learning(trainX,y_train)
pred = model1.predict(trainX["days"].values.reshape(-1,1)) + model2.predict(trainX.iloc[:,~trainX.columns.str.match("y")])

p = pd.DataFrame({"actual":y_train,"pred":pred})
p.plot(figsize=(15,4))
print("RMSE",MSE(y_train,pred)**0.5)
# Out:
# RMSE 7.986229908417227

# %%
model1, model2 = learning(trainX,y_train)
pred = model1.predict(testX["days"].values.reshape(-1,1)) + model2.predict(testX.iloc[:,~testX.columns.str.match("y")])
plt.figure(figsize=(15,4))
plt.plot(pred)

# %%
sample
# Out:
#              0   1
# 0    2014-10-1  24
# 1    2014-10-2  71
# 2    2014-10-3  25
# 3    2014-10-6  32
# 4    2014-10-7  60
# 5    2014-10-8  44
# 6    2014-10-9  64
# 7   2014-10-10  33
# 8   2014-10-14  67
# 9   2014-10-15  28
# 10  2014-10-16  90
# 11  2014-10-17  73
# 12  2014-10-20   9
# 13  2014-10-21  76
# 14  2014-10-22   1
# 15  2014-10-23  99
# 16  2014-10-24  73
# 17  2014-10-27  60
# 18  2014-10-28  99
# 19  2014-10-29  69
# 20  2014-10-30  68
# 21  2014-10-31  35
# 22   2014-11-4   2
# 23   2014-11-5  24
# 24   2014-11-6  10
# 25   2014-11-7  16
# 26  2014-11-10  43
# 27  2014-11-11  20
# 28  2014-11-12  88
# 29  2014-11-13  18
# 30  2014-11-14  63
# 31  2014-11-17  23
# 32  2014-11-18  55
# 33  2014-11-19  83
# 34  2014-11-20  87
# 35  2014-11-21  55
# 36  2014-11-25  47
# 37  2014-11-26  60
# 38  2014-11-27  80
# 39  2014-11-28  77

# %%
sample[1] = pred
sample
# Out:
#              0           1
# 0    2014-10-1   48.507383
# 1    2014-10-2   48.340275
# 2    2014-10-3   46.234835
# 3    2014-10-6   52.865906
# 4    2014-10-7   45.820344
# 5    2014-10-8   49.467576
# 6    2014-10-9   47.304049
# 7   2014-10-10  110.109083
# 8   2014-10-14   46.022597
# 9   2014-10-15   51.355070
# 10  2014-10-16   44.576873
# 11  2014-10-17   45.400861
# 12  2014-10-20   45.050974
# 13  2014-10-21   45.813195
# 14  2014-10-22   45.605950
# 15  2014-10-23   50.378964
# 16  2014-10-24   84.645872
# 17  2014-10-27   44.014748
# 18  2014-10-28   43.950145
# 19  2014-10-29   43.742900
# 20  2014-10-30   42.504421
# 21  2014-10-31   44.195371
# 22   2014-11-4   42.089931
# 23   2014-11-5   43.780880
# 24   2014-11-6   43.573635
# 25   2014-11-7  106.460239
# 26  2014-11-10   42.292183
# 27  2014-11-11   43.317009
# 28  2014-11-12   42.744654
# 29  2014-11-13   41.670448
# 30  2014-11-14   41.463203
# 31  2014-11-17   41.113315
# 32  2014-11-18   41.048712
# ...

# %%
sample.to_csv("submit01.csv")

# %%
sample.to_csv("/content/drive/MyDrive/Colab Notebooks/signate_obentou/submit01.csv",index=None,header=None)

# %%
/content/drive/MyDrive/Colab Notebooks/signate_obentou/sample.csv
