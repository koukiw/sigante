# %% [markdown]
# https://zenn.dev/murakamixi/articles/9b7f63f6eb79ad

# %%
from pycaret.datasets import get_data
boston_data = get_data('boston')
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
boston_data.shape
# Out:
# (506, 14)

# %%
import pandas as pd

# %%
from pycaret.regression import *
exp1 = setup(boston_data, target = 'medv')
# Out:
# <style type="text/css">
# </style>
# <table id="T_7a0ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a0ef_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7a0ef_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a0ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a0ef_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_7a0ef_row0_col1" class="data row0 col1" >1883</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7a0ef_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7a0ef_row1_col1" class="data row1 col1" >medv</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7a0ef_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_7a0ef_row2_col1" class="data row2 col1" >(506, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7a0ef_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_7a0ef_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7a0ef_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_7a0ef_row4_col1" class="data row4 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7a0ef_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_7a0ef_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7a0ef_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_7a0ef_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7a0ef_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_7a0ef_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7a0ef_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_7a0ef_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7a0ef_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_7a0ef_row9_col1" class="data row9 col1" >(354, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7a0ef_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_7a0ef_row10_col1" class="data row10 col1" >(152, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7a0ef_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_7a0ef_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7a0ef_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_7a0ef_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7a0ef_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_7a0ef_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7a0ef_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_7a0ef_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7a0ef_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_7a0ef_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7a0ef_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_7a0ef_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7a0ef_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_7a0ef_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7a0ef_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_7a0ef_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7a0ef_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_7a0ef_row19_col1" class="data row19 col1" >c191</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_7a0ef_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_7a0ef_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_7a0ef_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_7a0ef_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_7a0ef_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_7a0ef_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_7a0ef_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_7a0ef_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_7a0ef_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_7a0ef_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_7a0ef_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_7a0ef_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_7a0ef_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_7a0ef_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_7a0ef_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_7a0ef_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_7a0ef_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_7a0ef_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_7a0ef_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_7a0ef_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7a0ef_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_7a0ef_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_7a0ef_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <tr>
#       <th id

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_dbcc7 th {
#   text-align: left;
# }
# #T_dbcc7_row0_col0, #T_dbcc7_row0_col1, #T_dbcc7_row0_col2, #T_dbcc7_row0_col3, #T_dbcc7_row0_col5, #T_dbcc7_row0_col6, #T_dbcc7_row1_col0, #T_dbcc7_row1_col1, #T_dbcc7_row1_col2, #T_dbcc7_row1_col3, #T_dbcc7_row1_col4, #T_dbcc7_row1_col5, #T_dbcc7_row1_col6, #T_dbcc7_row2_col0, #T_dbcc7_row2_col1, #T_dbcc7_row2_col2, #T_dbcc7_row2_col3, #T_dbcc7_row2_col4, #T_dbcc7_row2_col5, #T_dbcc7_row2_col6, #T_dbcc7_row3_col0, #T_dbcc7_row3_col1, #T_dbcc7_row3_col2, #T_dbcc7_row3_col3, #T_dbcc7_row3_col4, #T_dbcc7_row3_col5, #T_dbcc7_row3_col6, #T_dbcc7_row4_col0, #T_dbcc7_row4_col1, #T_dbcc7_row4_col2, #T_dbcc7_row4_col3, #T_dbcc7_row4_col4, #T_dbcc7_row4_col5, #T_dbcc7_row4_col6, #T_dbcc7_row5_col0, #T_dbcc7_row5_col1, #T_dbcc7_row5_col2, #T_dbcc7_row5_col3, #T_dbcc7_row5_col4, #T_dbcc7_row5_col5, #T_dbcc7_row5_col6, #T_dbcc7_row6_col0, #T_dbcc7_row6_col1, #T_dbcc7_row6_col2, #T_dbcc7_row6_col3, #T_dbcc7_row6_col4, #T_dbcc7_row6_col5, #T_dbcc7_row6_col6, #T_dbcc7_row7_col0, #T_dbcc7_row7_col1, #T_dbcc7_row7_col2, #T_dbcc7_row7_col3, #T_dbcc7_row7_col4, #T_dbcc7_row7_col5, #T_dbcc7_row7_col6, #T_dbcc7_row8_col0, #T_dbcc7_row8_col1, #T_dbcc7_row8_col2, #T_dbcc7_row8_col3, #T_dbcc7_row8_col4, #T_dbcc7_row8_col5, #T_dbcc7_row8_col6, #T_dbcc7_row9_col0, #T_dbcc7_row9_col1, #T_dbcc7_row9_col2, #T_dbcc7_row9_col3, #T_dbcc7_row9_col4, #T_dbcc7_row9_col5, #T_dbcc7_row9_col6, #T_dbcc7_row10_col0, #T_dbcc7_row10_col1, #T_dbcc7_row10_col2, #T_dbcc7_row10_col3, #T_dbcc7_row10_col4, #T_dbcc7_row10_col5, #T_dbcc7_row10_col6, #T_dbcc7_row11_col0, #T_dbcc7_row11_col1, #T_dbcc7_row11_col2, #T_dbcc7_row11_col3, #T_dbcc7_row11_col4, #T_dbcc7_row11_col5, #T_dbcc7_row11_col6, #T_dbcc7_row12_col0, #T_dbcc7_row12_col1, #T_dbcc7_row12_col2, #T_dbcc7_row12_col3, #T_dbcc7_row12_col4, #T_dbcc7_row12_col5, #T_dbcc7_row12_col6, #T_dbcc7_row13_col0, #T_dbcc7_row13_col1, #T_dbcc7_row13_col2, #T_dbcc7_row13_col3, #T_dbcc7_row13_col4, #T_dbcc7_row13_col5, #T_dbcc7_row13_col6, #T_dbcc7_row14_col0, #T_dbcc7_row14_col1, #T_dbcc7_row14_col2, #T_dbcc7_row14_col3, #T_dbcc7_row14_col4, #T_dbcc7_row14_col5, #T_dbcc7_row14_col6, #T_dbcc7_row15_col0, #T_dbcc7_row15_col4, #T_dbcc7_row16_col0, #T_dbcc7_row16_col1, #T_dbcc7_row16_col2, #T_dbcc7_row16_col3, #T_dbcc7_row16_col4, #T_dbcc7_row16_col5, #T_dbcc7_row16_col6, #T_dbcc7_row17_col0, #T_dbcc7_row17_col1, #T_dbcc7_row17_col2, #T_dbcc7_row17_col3, #T_dbcc7_row17_col4, #T_dbcc7_row17_col5, #T_dbcc7_row17_col6 {
#   text-align: left;
# }
# #T_dbcc7_row0_col4, #T_dbcc7_row15_col1, #T_dbcc7_row15_col2, #T_dbcc7_row15_col3, #T_dbcc7_row15_col5, #T_dbcc7_row15_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_dbcc7_row0_col7, #T_dbcc7_row1_col7, #T_dbcc7_row2_col7, #T_dbcc7_row3_col7, #T_dbcc7_row4_col7, #T_dbcc7_row5_col7, #T_dbcc7_row8_col7, #T_dbcc7_row9_col7, #T_dbcc7_row10_col7, #T_dbcc7_row12_col7, #T_dbcc7_row14_col7, #T_dbcc7_row15_col7, #T_dbcc7_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_dbcc7_row6_col7, #T_dbcc7_row7_col7, #T_dbcc7_row11_col7, #T_dbcc7_row13_col7, #T_dbcc7_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_dbcc7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbcc7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_dbcc7_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_dbcc7_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_dbcc7_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_dbcc7_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_dbcc7_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_dbcc7_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_dbcc7_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbcc7_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_dbcc7_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_dbcc7_row0_col1" class="data row0 col1" >2.0842</td>
#       <td id="T_dbcc7_row0_col2" class="data row0 col2" >9.7262</td>
#       <td id="T_dbcc7_row0_col3" class="data row0 col3" >2.9860</td>
#       <td id="T_dbcc7_row0_col4" class="data row0 col4" >0.8871</td>
#       <td id="T_dbcc7_row0_col5" class="data row0 col5" >0.1310</td>
#       <td id="T_dbcc7_row0_col6" class="data row0 col6" >0.1020</td>
#       <td id="T_dbcc7_row0_col7" class="data row0 col7" >0.2830</td>
#     </tr>
#     <tr>
#       <th id="T_dbcc7_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_dbcc7_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_dbcc7_row1_col1" class="data row1 col1" >2.1455</td>
#       <td id="T_dbcc7_row1_col2" class="data row1 col2" >10.8770</td>
#       <td id="T_dbcc7_row1_col3" class="data row1 col3" >3.1414</td>
#       <td id="T_dbcc7_row1_col4" class="data row1 col4" >0.8738</td>
#       <td id="T_dbcc7_row1_col5" class="data row1 col5" >0.1364</td>
#       <td id="T_dbcc7_row1_col6" class="data row1 col6" >0.1057</td>
#       <td id="T_dbcc7_row1_col7" class="data row1 col7" >0.0360</td>
#     </tr>
#     <tr>
#       <th id="T_dbcc7_level0_row2" class="row_heading level0 row2" >gbr</th>
#       <td id="T_dbcc7_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_dbcc7_row2_col1" class="data row2 col1" >2.3364</td>
#       <td id="T_dbcc7_row2_col2" class="data row2 col2" >12.0663</td>
#       <td id="T_dbcc7_row2_col3" class="data row2 col3" >3.3208</td>
#       <td id="T_dbcc7_row2_col4" class="data row2 col4" >0.8512</td>
#       <td id="T_dbcc7_row2_col5" class="data row2 col5" >0.1500</td>
#       <td id="T_dbcc7_row2_col6" class="data row2 col6" >0.1177</td>
#       <td id="T_dbcc7_row2_col7" class="data row2 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_dbcc7_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_dbcc7_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_dbcc7_row3_col1" class="data row3 col1" >2.4472</td>
#       <td id="T_dbcc7_row3_col2" class="data row3 col2" >13.5231</td>
#       <td id="T_dbcc7_row3_col3" class="data row3 col3" >3.5378</td>
#       <td id="T_dbcc7_row3_col4" class="data row3 col4" >0.8407</td>
#       <td id="T_dbcc7_row3_col5" class="data row3 col5" >0.1562</td>
#       <td id="T_dbcc7_row3_col6" class="data row3 col6" >0.1216</td>
#       <td id="T_dbcc7_row3_col7" class="data row3 col7" >0.2180</td>
#     </tr>
#     <tr>
#       <th id="T_dbcc7_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_dbcc7_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_dbcc7_row4_col1" class="data row4 col1" >2.3778</td>
#       <td id="T_dbcc7_row4_col2" class="data row4 col2" >13.3770</td>
#       <td id="T_dbcc7_row4_col3" class="data row4 col3" >3.4851</td>
#       <td id="T_dbcc7_row4_col4" class="data row4 col4" >0.8393</td>
#       <td id="T_dbcc7_row4_col5" class="data row4 col5" >0.1505</td>
#       <td id="T_dbcc7_row4_col6" class="data row4 col6" >0.1180</td>
#       <td id="T_dbcc7_row4_col7" class="data row4 col7" >0.0460</td>
#     </tr>
#     <tr>
#       <th id="T_dbcc7_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_dbcc7_row5_col0" class="data row5 col0" >AdaBoost Regressor</td>
#       <td id="T_dbcc7_row5_col1" class="data row5 col1" >2.9845</td>
#       <td id="T_dbcc7_row5_col2" class="data row5 col2" >18.5438</td>
#       <td id="T_dbcc7_row5_col3" class="data row5 col3" >4.1221</td>
#       <td id="T_dbcc7_row5_col4" class="data row5 col4" >0.7854</td>
#       <td id="T_dbcc7_row5_col5" class="data row5 col5" >0.1857</td>
#       <td id="T_dbcc7_row5_col6" class="data row5 col6" >0.1545</td>
#       <td id="T_dbcc7_row5_col7" class="data row5 col7" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_dbcc7_le

# %%
rf = create_model('rf')
# Out:
# <style type="text/css">
# #T_6b578_row10_col0, #T_6b578_row10_col1, #T_6b578_row10_col2, #T_6b578_row10_col3, #T_6b578_row10_col4, #T_6b578_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_6b578">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b578_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_6b578_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_6b578_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_6b578_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_6b578_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_6b578_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b578_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6b578_row0_col0" class="data row0 col0" >2.2903</td>
#       <td id="T_6b578_row0_col1" class="data row0 col1" >10.8872</td>
#       <td id="T_6b578_row0_col2" class="data row0 col2" >3.2996</td>
#       <td id="T_6b578_row0_col3" class="data row0 col3" >0.8764</td>
#       <td id="T_6b578_row0_col4" class="data row0 col4" >0.1808</td>
#       <td id="T_6b578_row0_col5" class="data row0 col5" >0.1411</td>
#     </tr>
#     <tr>
#       <th id="T_6b578_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6b578_row1_col0" class="data row1 col0" >1.8045</td>
#       <td id="T_6b578_row1_col1" class="data row1 col1" >5.6877</td>
#       <td id="T_6b578_row1_col2" class="data row1 col2" >2.3849</td>
#       <td id="T_6b578_row1_col3" class="data row1 col3" >0.9071</td>
#       <td id="T_6b578_row1_col4" class="data row1 col4" >0.1048</td>
#       <td id="T_6b578_row1_col5" class="data row1 col5" >0.0895</td>
#     </tr>
#     <tr>
#       <th id="T_6b578_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6b578_row2_col0" class="data row2 col0" >2.5529</td>
#       <td id="T_6b578_row2_col1" class="data row2 col1" >13.5856</td>
#       <td id="T_6b578_row2_col2" class="data row2 col2" >3.6859</td>
#       <td id="T_6b578_row2_col3" class="data row2 col3" >0.9149</td>
#       <td id="T_6b578_row2_col4" class="data row2 col4" >0.1467</td>
#       <td id="T_6b578_row2_col5" class="data row2 col5" >0.1197</td>
#     </tr>
#     <tr>
#       <th id="T_6b578_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6b578_row3_col0" class="data row3 col0" >3.2611</td>
#       <td id="T_6b578_row3_col1" class="data row3 col1" >27.8400</td>
#       <td id="T_6b578_row3_col2" class="data row3 col2" >5.2764</td>
#       <td id="T_6b578_row3_col3" class="data row3 col3" >0.5651</td>
#       <td id="T_6b578_row3_col4" class="data row3 col4" >0.2269</td>
#       <td id="T_6b578_row3_col5" class="data row3 col5" >0.1809</td>
#     </tr>
#     <tr>
#       <th id="T_6b578_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6b578_row4_col0" class="data row4 col0" >1.6085</td>
#       <td id="T_6b578_row4_col1" class="data row4 col1" >4.7417</td>
#       <td id="T_6b578_row4_col2" class="data row4 col2" >2.1775</td>
#       <td id="T_6b578_row4_col3" class="data row4 col3" >0.9161</td>
#       <td id="T_6b578_row4_col4" class="data row4 col4" >0.1047</td>
#       <td id="T_6b578_row4_col5" class="data row4 col5" >0.0826</td>
#     </tr>
#     <tr>
#       <th id="T_6b578_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6b578_row5_col0" class="data row5 col0" >2.9941</td>
#       <td id="T_6b578_row5_col1" class="data row5 col1" >32.4508</td>
#       <td id="T_6b578_row5_col2" class="data row5 col2" >5.6966</td>
#       <td id="T_6b578_row5_col3" class="data row5 col3" >0.7788</td>
#       <td id="T_6b578_row5_col4" class="data row5 col4" >0.1883</td>
#       <td id="T_6b578_row5_col5" class="data row5 col5" >0.1211</td>
#     </tr>
#     <tr>
#       <th id="T_6b578_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6b578_row6_col0" class="data row6 col0" >2.4782</td>
#       <td id="T_6b578_row6_col1" class="data row6 col1" >10.7911</td>
#       <td id="T_6b578_row6_col2" class="data row6 col2" >3.2850</td>
#       <td id="T_6b578_row6_col3" class="data row6 col3" >0.8781</td>
#       <td id="T_6b578_row6_col4" class="data row6 col4" >0.1859</td>
#       <td id="T_6b578_row6_col5" class="data row6 col5" >0.1454</td>
#     </tr>
#     <tr>
#       <th id="T_6b578_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6
td>
#     </tr>
#     <tr>
#       <th id="T_51818_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_51818_row10_col0" class="data row10 col0" >2.4869</td>
#       <td id="T_51818_row10_col1" class="data row10 col1" >13.7343</td>
#       <td id="T_51818_row10_col2" class="data row10 col2" >3.5510</td>
#       <td id="T_51818_row10_col3" class="data row10 col3" >0.8437</td>
#       <td id="T_51818_row10_col4" class="data row10 col4" >0.1479</td>
#       <td id="T_51818_row10_col5" class="data row10 col5" >0.1206</td>
#     </tr>
#     <tr>
#       <th id="T_51818_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_51818_row11_col0" class="data row11 col0" >0.5000</td>
#       <td id="T_51818_row11_col1" class="data row11 col1" >8.4913</td>
#       <td id="T_51818_row11_col2" class="data row11 col2" >1.0605</td>
#       <td id="T_51818_row11_col3" class="data row11 col3" >0.0667</td>
#       <td id="T_51818_row11_col4" class="data row11 col4" >0.0408</td>
#       <td id="T_51818_row11_col5" class="data row11 col5" >0.0301</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_rf = tune_model(rf,n_iter = 100, optimize = 'r2')
# Out:
# IntProgress(value=0, description='Processing: ', max=7)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                 03:55:52
# Status     . . . . . . . . . . . . . . . . . .         Finalizing Model
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Regressor
# Empty DataFrame
# Columns: [MAE, MSE, RMSE, R2, RMSLE, MAPE]
# Index: []
# Fitting 10 folds for each of 500 candidates, totalling 5000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   17.2s
# /Users/kouki/opt/anaconda3/envs/pycaret/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/kouki/opt/anaconda3/envs/pycaret/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/kouki/opt/anaconda3/envs/pycaret/lib/python3.9/site-packages/pycaret/internal/pipeline.py", line 120, in fit
#     self._carry_over_final_estimator_fit_vars()
#   File "/Users/kouki/opt/anaconda3/envs/pycaret/lib/python3.9/site-packages/pycaret/internal/pipeline.py", line 57, in _carry_over_final_estimator_fit_vars
#     for k, v in get_all_object_vars_and_properties(
#   File "/Users/kouki/opt/anaconda3/envs/pycaret/lib/python3.9/site-packages/pycaret/internal/utils.py", line 562, in get_all_object_vars_and_properties
#     return {
#   File "/Users/kouki/opt/anaconda3/envs/pycaret/lib/python3.9/site-packages/pycaret/internal/utils.py", line 565, in <dictcomp>
#     if k[:2] != "__" and type(getattr(object, k, "")).__name__ != "method"
#   File "/Users/kouki/opt/anaconda3/envs/pycaret/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 446, in feature_importances_
#     all_importances = Parallel(n_jobs=self.n_jobs,
#   File "/Users/kouki/opt/anaconda3/envs/pycaret/lib/python3.9/site-packages/joblib/parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/kouki/opt/anaconda3/envs/pycaret/lib/python3.9/site-packages/joblib/parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/kouki/opt/anaconda3/envs/pycaret/lib/python3.9/site-packages/joblib/parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/kouki/opt/anaconda3/envs/pycaret/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 252, in apply_async
#     return self._get_pool().apply_async(
#   File "/Users/kouki/opt/anaconda3/envs/pycaret/lib/python3.9/multiprocessing/pool.py", line 455, in apply_async
#     self._check_running()
#   File "/Users/kouki/opt/anaconda3/envs/pycaret/lib/python3.9/multiprocessing/pool.py", line 350, in _check_running
#     raise ValueError("Pool not running")
# ValueError: Pool not running
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 tuned_rf = tune_model(rf,n_iter = 500, optimize = 'r2')
#
# File ~/opt/anaconda3/envs/pycaret/lib/python3.9/site-packages/pycaret/regression.py:1082, in tune_model(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, **kwargs)
#     899 def tune_model(
#     900     estimator,
#     901     fold: Optional[Union[int, Any]] = None,
#    (...)
#     917     **kwargs,
#     918 ):
#     920     """
#     921     This function tunes the hyperparameters of a given estimator. The output of
#     922     this function is a score grid with CV scores by fold of the best selected
#    (...)
#    1079
#    1080     """
# -> 1082     return pycaret.internal.tabular.tune_model_supervised(
#    1083         estimator=estimator,
#    1084         fold=fold,
#    1085         round=round,
#    1086         n_iter=n_iter,
#    1087         custom_grid=custom_grid,
#    1088         optimize=optimize,
#    1089         custom_scorer=custom_scorer,
#    1090         search_library=search_library,
#    1091         search_algorithm=search_algorithm,
#    1092         early_stopping=early_stopping,
#    1093         early_stopping_max_iters=early_stopping_max_iters,
#    1094         choose_better=choose_better,
#    1095         fit_kwargs=fit_kwargs,
#    1096         groups=groups,
#    1097         return_tuner=return_tuner,
#    1098         verbose=verbose,
#    1099         tuner_verbose=tuner_verbose,
#    1100         **kwargs,
#    1101     )
#
# File ~/opt/anaconda3/envs/pycaret/lib/python3.9/site-packages/pycaret/internal/tabular.py:4455, in tune_model_supervised(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, display, **kwargs)
#    4447     with patch(
#    4448         "sklearn.model_selection._search.sample_without_replacement",
#    4449         pycaret.internal.patches.sklearn._mp_sample_without_replacement,
#    4450     ):
#    4451         with patch(
#    4452             "sklearn.model_selection._search.ParameterGrid.__getitem__",
#    4453             pycaret.internal.patches.sklearn._mp_ParameterGrid_getitem,
#    4454         ):
# -> 4455             model_grid.fit(X_train, y_train, groups=groups, **fit_kwargs)
#    4456 else:
#    4457     model_grid.fit(X_train, y_train, groups=groups, **fit_kwargs)
#
# File ~/opt/anaconda3/envs/pycaret/lib/python3.9/site-packages/sklearn/utils/validation.py:72, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      67     warnings.warn("Pass {} as keyword args. From version 0.25 "
#      68                   "passing these as positional arguments will "
#      69                   "result in an error".format(", ".join(args_msg)),
#      70                   FutureWarning)
#      71 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72 return f(**kwargs)
#
# File ~/opt/anaconda3/envs/pycaret/lib/python3.9/site-packages/sklearn/model_selection/_search.py:736, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     732         results = self._format_results(
#     733             all_candidate_params, scorers, n_splits, all_out)
#     734         return results
# --> 736     self._run_search(evaluate_candidates)
#     738 # For multi-metric evaluation, store the best_index_, best_params_ and
#     739 # best_score_ iff refit is one of the scorer names
#     740 # In single metric evaluation, refit_metric is "score"
#     741 if self.refit or not self.multimetric_:
#     742     # If callable, refit is expected to return the index of the best
#     743     # parameter set.
#
# File ~/opt/anaconda3/envs/pycaret/lib/python3.9/site-packages/sklearn/model_selection/_search.py:1529, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1527 def _run_search(self, evaluate_candidates):
#    1528     """Search n_iter candidates from param_distributions"""
# -> 1529     evaluate_candidates(ParameterSampler(
#    1530         self.param_distributions, self.n_iter,
#    1531         random_state=self.random_state))
#
# File ~/opt/anaconda3/envs/pycaret/lib/python3.9/site-packages/sklearn/model_selection/_search.py:708, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params)
#     703 if self.verbose > 0:
#     704     print("Fitting {0} folds for each of {1} candidates,"
#     705           " totalling {2} fits".format(
#     706               n_splits, n_candidates, n_candidates * n_splits))
# --> 708 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     709                                        X, y,
#     710                                        train=train, test=test,
#     711                                        parameters=parameters,
#     712                                        **fit_and_score_kwargs)
#     713                for parameters, (train, test)
#     714                in product(candidate_params,
#     715                           cv.split(X, y, groups)))
#     717 if len(out) < 1:
#     718     raise ValueError('No fits were performed. '
#     719                      'Was the CV iterator empty? '
#     720                      'Were there no candidates?')
#
# File ~/opt/anaconda3/envs/pycaret/lib/python3.9/site-packages/joblib/parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File ~/opt/anaconda3/envs/pycaret/lib/python3.9/site-packages/joblib/parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File ~/opt/anaconda3/envs/pycaret/lib/python3.9/site-packages/joblib/_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File ~/opt/anaconda3/envs/pycaret/lib/python3.9/concurrent/futures/_base.py:440, in Future.result(self, timeout)
#     437 elif self._state == FINISHED:
#     438     return self.__get_result()
# --> 440 self._condition.wait(timeout)
#     442 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     443     raise CancelledError()
#
# File ~/opt/anaconda3/envs/pycaret/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
tuned_rf.get_params
# Out:
# <bound method BaseEstimator.get_params of RandomForestRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mae',
#                       max_depth=10, max_features='log2', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.005,
#                       min_impurity_split=None, min_samples_leaf=2,
#                       min_samples_split=7, min_weight_fraction_leaf=0.0,
#                       n_estimators=130, n_jobs=-1, oob_score=False,
#                       random_state=1883, verbose=0, warm_start=False)>

# %%
plot_model(tuned_rf)

# %%
interpret_model(tuned_rf)

# %%
rf_holdout_pred = predict_model(rf)
# Out:
# <style type="text/css">
# </style>
# <table id="T_da639">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da639_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_da639_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_da639_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_da639_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_da639_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_da639_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_da639_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da639_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_da639_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_da639_row0_col1" class="data row0 col1" >2.0792</td>
#       <td id="T_da639_row0_col2" class="data row0 col2" >9.0555</td>
#       <td id="T_da639_row0_col3" class="data row0 col3" >3.0092</td>
#       <td id="T_da639_row0_col4" class="data row0 col4" >0.8798</td>
#       <td id="T_da639_row0_col5" class="data row0 col5" >0.1477</td>
#       <td id="T_da639_row0_col6" class="data row0 col6" >0.1144</td>
#     </tr>
#   </tbody>
# </table>

# %%
predictions = predict_model(rf, data=boston_data)

# %%
predictions
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv      Label
# 0       15.3  396.90   4.98  24.0  25.673000
# 1       17.8  396.90   9.14  21.6  21.793000
# 2       17.8  392.83   4.03  34.7  34.550001
# 3       18.7  394.63   2.94  33.4  33.529001
# 4       18.7  396.90   5.33  36.2  33.748001
# ..       ...     ...    ...   ...        ...
# 501     21.0  391.99   9.67  22.4  23.532000
# 502     21.0  396.90   9.08  20.6  19.861000
# 503     21.0  396.90   5.64  23.9  27.896000
# 504     21.0  393.45   6.48  22.0  24.887000
# 505     21.0  396.90   7.88  11.9  15.057000
#
# [506 rows x 15 columns]
